# %%
import pandas as pd

# %%
df = pd.read_csv("data2.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.loc[1]
# Out:
# Actor                       Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %%
df.loc[3, 'Film']
# Out:
# 'Brahmastra'

# %%
df.iloc[7, 5]
# Out:
# np.float64(6.5)

# %%
df.loc[8, 'Genre']
# Out:
# 'Comedy'

# %%
df.loc[0:4, ['Actor', 'Film']]
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai
# 2      Aamir Khan           Dangal
# 3   Ranbir Kapoor       Brahmastra
# 4   Ranveer Singh        Padmaavat

# %%
df[(df['IMDb'] > 6) & (df['Year'] > 2020)]
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
df[["Actor", "IMDb"]]
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df['Actor'][0]
# Out:
# 'Shah Rukh Khan'

# %%
df.query("Year > 2018 and IMDb > 6")
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df.query("`Year` > 2018")
# Out:
#              Actor                      Film  Year          Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023         Action
# 3    Ranbir Kapoor                Brahmastra  2022        Fantasy
# 7   Hrithik Roshan                       War  2019         Action
# 8     Akshay Kumar                Good Newwz  2019         Comedy
# 9    Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 11                   342   8.2

# %%
year = 2018

# %%
df.query("Year >= @year")
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 3        Ranbir Kapoor                Brahmastra  2022        Fantasy
# 4        Ranveer Singh                 Padmaavat  2018     Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 7       Hrithik Roshan                       War  2019         Action
# 8         Akshay Kumar                Good Newwz  2019         Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# ...

# %%
df2 = df[["Actor", "IMDb"]].copy()

# %%
df2
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.loc[0, ['Actor']] = "Rugved"

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2
# Out:
#                  Actor  IMDb
# 0               Rugved   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.loc[1, "Name"]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
df['Age'].value_counts().head()
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 30.0    25
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Pclass'] = df['Pclass'].astype('category')
df['Survived'] = df['Survived'].astype('category')

# %%
df
# Out:
#      PassengerId Survived Pclass  \
# 0              1        0      3
# 1              2        1      1
# 2              3        1      3
# 3              4        1      1
# 4              5        0      3
# ..           ...      ...    ...
# 886          887        0      2
# 887          888        1      1
# 888          889        0      3
# 889          890        1      1
# 890          891        0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId       int64
# Survived       category
# Pclass         category
# Name             object
# Sex              object
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked         object
# dtype: object

# %%
df.iloc[2:5, 4:7]
# Out:
#       Sex   Age  SibSp
# 2  female  26.0      0
# 3  female  35.0      1
# 4    male  35.0      0

# %%
df.loc[:, 'Sex':'Fare']
# Out:
#         Sex   Age  SibSp  Parch            Ticket     Fare
# 0      male  22.0      1      0         A/5 21171   7.2500
# 1    female  38.0      1      0          PC 17599  71.2833
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250
# 3    female  35.0      1      0            113803  53.1000
# 4      male  35.0      0      0            373450   8.0500
# ..      ...   ...    ...    ...               ...      ...
# 886    male  27.0      0      0            211536  13.0000
# 887  female  19.0      0      0            112053  30.0000
# 888  female   NaN      1      2        W./C. 6607  23.4500
# 889    male  26.0      0      0            111369  30.0000
# 890    male  32.0      0      0            370376   7.7500
#
# [891 rows x 6 columns]

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2 = df.copy()

# %%
df2 = df.sort_values(["Year", "IMDb"], ascending=False).copy()

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 3        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5       Hrithik Roshan                       War  2019           Action
# 6   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7        Rajkummar Rao                     Stree  2018    Horror Comedy
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 10         Salman Khan           Tiger Zinda Hai  2017           Action
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2['Rank'] = df2['IMDb'].rank(ascending=False, method="dense")

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df2 = df2[["Film", "Actor", "Year", "Genre", "IMDb", "Rank", "BoxOffice(INR Crore)",]]

# %%
df2
# Out:
#                         Film               Actor  Year            Genre  IMDb  \
# 0                    Pathaan      Shah Rukh Khan  2023           Action   7.2
# 1            Tiger Zinda Hai         Salman Khan  2017           Action   6.0
# 2                     Dangal          Aamir Khan  2016        Biography   8.4
# 3                 Brahmastra       Ranbir Kapoor  2022          Fantasy   5.6
# 4                  Padmaavat       Ranveer Singh  2018       Historical   7.0
# 5                  Andhadhun  Ayushmann Khurrana  2018         Thriller   8.3
# 6                      Stree       Rajkummar Rao  2018    Horror Comedy   7.5
# 7                        War      Hrithik Roshan  2019           Action   6.5
# 8                 Good Newwz        Akshay Kumar  2019           Comedy   7.0
# 9          Bhool Bhulaiyaa 2       Kartik Aaryan  2022    Horror Comedy   5.9
# 10     Badrinath Ki Dulhania        Varun Dhawan  2017  Romantic Comedy   6.1
# ...

# %%
df2.rename(columns={"Film" : "FILM"}, inplace=True)

# %%
df2
# Out:
#                         FILM               Actor  Year            Genre  IMDb  \
# 0                    Pathaan      Shah Rukh Khan  2023           Action   7.2
# 1            Tiger Zinda Hai         Salman Khan  2017           Action   6.0
# 2                     Dangal          Aamir Khan  2016        Biography   8.4
# 3                 Brahmastra       Ranbir Kapoor  2022          Fantasy   5.6
# 4                  Padmaavat       Ranveer Singh  2018       Historical   7.0
# 5                  Andhadhun  Ayushmann Khurrana  2018         Thriller   8.3
# 6                      Stree       Rajkummar Rao  2018    Horror Comedy   7.5
# 7                        War      Hrithik Roshan  2019           Action   6.5
# 8                 Good Newwz        Akshay Kumar  2019           Comedy   7.0
# 9          Bhool Bhulaiyaa 2       Kartik Aaryan  2022    Horror Comedy   5.9
# 10     Badrinath Ki Dulhania        Varun Dhawan  2017  Romantic Comedy   6.1
# ...

# %%
df2.columns
# Out:
# Index(['Actor', 'Film', 'Year', 'Genre', 'BoxOffice(INR Crore)', 'IMDb'], dtype='object')

# %%
cols = ["Actor"] + [col for col in df2.columns if col != "Actor"]

# %%
df2 = df2[cols]

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  IMDb  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action   7.2
# 1          Salman Khan           Tiger Zinda Hai  2017           Action   6.0
# 2           Aamir Khan                    Dangal  2016        Biography   8.4
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy   5.6
# 4        Ranveer Singh                 Padmaavat  2018       Historical   7.0
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller   8.3
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy   7.5
# 7       Hrithik Roshan                       War  2019           Action   6.5
# 8         Akshay Kumar                Good Newwz  2019           Comedy   7.0
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy   5.9
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy   6.1
# ...

# %%
# !pip install scikit-learn --upgrade
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.0 MB 6.3 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/8.0 MB 5.9 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/8.0 MB 5.4 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 5.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/8.0 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...
