# %%
import pandas as pd

# %%
s = pd.Series([12, 65, 78, 98, 90, 56])

# %%
s
# Out:
# 0    12
# 1    65
# 2    78
# 3    98
# 4    90
# 5    56
# dtype: int64

# %%
print(s[0])
# Out:
# 12

# %%
s2 = pd.Series([12, 65, 78, 98, 90], index = ["kedar", "shreehan", "chile", "Rugved", "raj"])

# %%
s2
# Out:
# kedar       12
# shreehan    65
# chile       78
# Rugved      98
# raj         90
# dtype: int64

# %%
print(s2["kedar"])
# Out:
# 12

# %%
print(s2["Rugved"])
# Out:
# 98

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
data = {

    "name" : ["Rugved", "kedar", "shreehan"],
    "age"  : [20, 35, 10],
    "city" : ["Mumbai", "delhi", "up"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        name  age    city
# 0    Rugved   20  Mumbai
# 1     kedar   35   delhi
# 2  shreehan   10      up

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
data2 = [["Rugved", 69], ["kedar", 10], ["shreehan", 20]]

# %%
df = pd.DataFrame(data2, columns = ["Name", "Marks"])

# %%
df
# Out:
#        Name  Marks
# 0    Rugved     69
# 1     kedar     10
# 2  shreehan     20

# %%
data3 = {"a" : [3, 5, 7], "b" : [8, 9, 1]}

# %%
df = pd.DataFrame(data3)

# %%
df
# Out:
#    a  b
# 0  3  8
# 1  5  9
# 2  7  1

# %%
import numpy as np

# %%
arr = np.array([[1, 2, 3], [5, 3, 7]])

# %%
df = pd.DataFrame(arr, columns = ["a", "b", "c"])

# %%
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  5  3  7

# %%
arr2 = np.array([1, 2, 3, 4])

# %%
df = pd.DataFrame(arr2, columns = ["A"])

# %%
df
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df = pd.read_excel("data.xlsx")

# %%
df
# Out:
#        Name school  marks
# 0   shubham    BBK     25
# 1    rugved    TFC     85
# 2     kedar    EDC      8
# 3    joshua    HFD     97
# 4  shreehan    NYG     46
# 5      alex    JYH     15
# 6     illia    BGV     74
# 7     islam    YGF    100

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#        Name school  marks
# 0   shubham    BBK     25
# 1    rugved    TFC     85
# 2     kedar    EDC      8
# 3    joshua    HFD     97
# 4  shreehan    NYG     46
# 5      alex    JYH     15
# 6     illia    BGV     74
# 7     islam    YGF    100

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.shape
# Out:
# (244, 7)

# %% [markdown]
# df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
