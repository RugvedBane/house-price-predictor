# %%
def send_telegram_message(message):
    import requests

    TOKEN = "8639543531:AAEmitnHWZRKLUB7RMC4xMAbIzRBCPVk5hI"
    CHAT_ID = "6598233825"

    url = f"https://api.telegram.org/bot{TOKEN}/sendMessage"
    data = {
        "chat_id": CHAT_ID,
        "text": message
    }

    requests.post(url, data=data)

# %%
send_telegram_message('test msg')
