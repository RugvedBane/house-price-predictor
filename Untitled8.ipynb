# %%
import pandas as pd
df = pd.read_csv("sample_data.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df.dropna()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df.dropna(axis=1)
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        Delhi      M    charlie@example

# %%
df.fillna(0)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5        0  28.0        Delhi      F     eve@domain.com           0
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   0.0        Delhi      M    charlie@example  20-07-2021

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    25.000000
# 1    25.833333
# 2    30.000000
# 3    25.833333
# 4    22.000000
# 5    28.000000
# 6    25.000000
# 7    25.000000
# 8    25.833333
# Name: Age, dtype: float64

# %%
df.ffill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    David  28.0        Delhi      F     eve@domain.com  12-11-2019
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  25.0        Delhi      M    charlie@example  20-07-2021

# %%
df.bfill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    Alice  28.0        Delhi      F     eve@domain.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.drop_duplicates()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.duplicated(subset = ["Name", "Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df['Name'].str.lower()
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3    charlie
# 4      david
# 5        NaN
# 6      alice
# 7      alice
# 8    charlie
# Name: Name, dtype: object

# %%
print(df['City'].str.contains("delhi", case=False).sum())
# Out:
# 4

# %%
df['Name'].str.contains("alice", case=False).sum()
# Out:
# 3

# %%
df['Email'].str.split("@")
# Out:
# 0    [alice, example.com]
# 1      [charlie, example]
# 2      [bob, example.com]
# 3      [charlie, example]
# 4    [david, example.com]
# 5       [eve, domain.com]
# 6    [alice, example.com]
# 7    [alice, example.com]
# 8      [charlie, example]
# Name: Email, dtype: object

# %%
type(df['Email'].str.split("@")[0])
# Out:
# list

# %%
df2 = df.dropna().copy()

# %%
df2
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df2['Age'] = df2['Age'].astype(int)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com  01-05-2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 4  David   22       Mumbai      M  david@example.com  12-11-2019
# 6  Alice   25     New York      F  alice@example.com  01-05-2021
# 7  Alice   25     New York      F  alice@example.com  01-05-2021

# %%
df2['Join Date'] = pd.to_datetime(df2['Join Date'], format = "%d-%m-%Y")

# %%
df2
# Out:
#     Name  Age         City Gender              Email  Join Date
# 0  Alice   25     New York      F  alice@example.com 2021-05-01
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15
# 4  David   22       Mumbai      M  david@example.com 2019-11-12
# 6  Alice   25     New York      F  alice@example.com 2021-05-01
# 7  Alice   25     New York      F  alice@example.com 2021-05-01

# %%
df2['Join Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int64
#  2   City       5 non-null      object
#  3   Gender     5 non-null      object
#  4   Email      5 non-null      object
#  5   Join Date  5 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 280.0+ bytes

# %%
df2
# Out:
#     Name  Age         City Gender              Email  Join Date
# 0  Alice   25     New York      F  alice@example.com 2021-05-01
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15
# 4  David   22       Mumbai      M  david@example.com 2019-11-12
# 6  Alice   25     New York      F  alice@example.com 2021-05-01
# 7  Alice   25     New York      F  alice@example.com 2021-05-01

# %%
df2['Age Group'] = df2['Age'].apply(lambda x: "Adult" if x >= 25 else "Minor")

# %%
df2
# Out:
#     Name  Age         City Gender              Email  Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com 2021-05-01     Adult
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15     Adult
# 4  David   22       Mumbai      M  david@example.com 2019-11-12     Minor
# 6  Alice   25     New York      F  alice@example.com 2021-05-01     Adult
# 7  Alice   25     New York      F  alice@example.com 2021-05-01     Adult

# %%
df3 = df2.copy()

# %%
df3
# Out:
#     Name  Age         City Gender              Email  Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com 2021-05-01     Adult
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15     Adult
# 4  David   22       Mumbai      M  david@example.com 2019-11-12     Minor
# 6  Alice   25     New York      F  alice@example.com 2021-05-01     Adult
# 7  Alice   25     New York      F  alice@example.com 2021-05-01     Adult

# %%
df3["From new york"] = df3['City'].apply(lambda city: True if city == "New York" else False)

# %%
df3
# Out:
#     Name  Age         City Gender              Email  Join Date Age Group  \
# 0  Alice   25     New York      F  alice@example.com 2021-05-01     Adult
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15     Adult
# 4  David   22       Mumbai      M  david@example.com 2019-11-12     Minor
# 6  Alice   25     New York      F  alice@example.com 2021-05-01     Adult
# 7  Alice   25     New York      F  alice@example.com 2021-05-01     Adult
#
#    From new york
# 0           True
# 2          False
# 4          False
# 6           True
# 7           True

# %%
gender_map = {"M" : "Male", "F" : "Female"}
df2["Gender"] = df2["Gender"].map(gender_map)

# %%
df2
# Out:
#     Name  Age         City  Gender              Email  Join Date Age Group
# 0  Alice   25     New York  Female  alice@example.com 2021-05-01     Adult
# 2    Bob   30  Los Angeles    Male    bob@example.com 2020-06-15     Adult
# 4  David   22       Mumbai    Male  david@example.com 2019-11-12     Minor
# 6  Alice   25     New York  Female  alice@example.com 2021-05-01     Adult
# 7  Alice   25     New York  Female  alice@example.com 2021-05-01     Adult

# %%
df2.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df2
# Out:
#     Name  Age         City Gender              Email  Join Date Age Group
# 0  Alice   25     New York    NaN  alice@example.com 2021-05-01     Adult
# 2    Bob   30  Los Angeles    NaN    bob@example.com 2020-06-15     Adult
# 4  David   22       Mumbai    NaN  david@example.com 2019-11-12     Minor
# 6  Alice   25     New York    NaN  alice@example.com 2021-05-01     Adult
# 7  Alice   25     New York    NaN  alice@example.com 2021-05-01     Adult

# %%
df2["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df2["City"] = df2["City"].replace({"New York" : "New Delhi", "Los Angeles" : "Mumbai"})

# %%
df2
# Out:
#     Name  Age       City  Gender              Email  Join Date Age Group
# 0  Alice   25  New Delhi  Female  alice@example.com 2021-05-01     Adult
# 2    Bob   30     Mumbai    Male    bob@example.com 2020-06-15     Adult
# 4  David   22     Mumbai    Male  david@example.com 2019-11-12     Minor
# 6  Alice   25  New Delhi  Female  alice@example.com 2021-05-01     Adult
# 7  Alice   25  New Delhi  Female  alice@example.com 2021-05-01     Adult
