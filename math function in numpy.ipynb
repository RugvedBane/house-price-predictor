# %%
import numpy as np

# %%
arr = np.array([3, 5, 4, 2, 6, 8, 9, 7])

# %%
print(np.mean(arr))
# Out:
# 5.5

# %%
print(np.max(arr))
# Out:
# 9

# %%
print(np.min(arr))
# Out:
# 2

# %%
print(np.std(arr))
# Out:
# 2.29128784747792

# %%
print(np.var(arr))
# Out:
# 5.25

# %%
print(np.sum(arr))
# Out:
# 44

# %%
print(np.prod(arr))
# Out:
# 362880

# %%
print(np.percentile(arr, 50))
# Out:
# 5.0

# %%
print(np.median(arr))
# Out:
# 5.0

# %%
print(np.argmin(arr))
# Out:
# 3

# %%
print(np.argmax(arr))
# Out:
# 6

# %%
arr2 = np.array([2, 4, 6, 8, 9, 7, 5, 4])

# %%
print(np.corrcoef(arr, arr2))
# Out:
# [[1.         0.03760887]
#  [0.03760887 1.        ]]

# %%
np.corrcoef(arr, arr2)
# Out:
# array([[1.        , 0.03760887],
#        [0.03760887, 1.        ]])

# %%
print(np.unique(arr))
# Out:
# [2 3 4 5 6 7 8 9]

# %%
print(np.diff(arr))
# Out:
# [ 2 -1 -2  4  2  1 -2]

# %%
print(np.cumsum(arr))
# Out:
# [ 3  8 12 14 20 28 37 44]

# %%
arr3 = np.linspace(0, 10, 5)

# %%
arr3
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.linspace(0, 10, 5,)
# Out:
# array([ 0,  2,  5,  7, 10], dtype=int32)

# %%
print(np.log(arr))
# Out:
# [1.09861229 1.60943791 1.38629436 0.69314718 1.79175947 2.07944154
#  2.19722458 1.94591015]

# %%
print(np.exp(arr))
# Out:
# [2.00855369e+01 1.48413159e+02 5.45981500e+01 7.38905610e+00
#  4.03428793e+02 2.98095799e+03 8.10308393e+03 1.09663316e+03]
