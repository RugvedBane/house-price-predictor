# %%
import json

def load_data(filename):
    with open(filename, "r") as f:
        return json.load(f)

def people_you_may_know(user_id, data):
    user_friends = {}
    for user in data['users']:
        user_friends[user['id']] = set(user['friends'])

    if user_id not in user_friends:
        return []

    direct_friends = user_friends[user_id]
    suggestions = {}

    for friend in direct_friends:
        for mutual in user_friends['friend']:
            if mutual != user_id and mutual not in direct_friends:
                
                suggestions[mutual] = suggestions.get(mutual, 0) + 1
        
        
    sorted_suggestions = sorted(suggestions.items(), key = lambda x: x[1], reverse=True)
        
    return [user_id for user_id, mutual_count in sorted_suggestions]
            

    

data = load_data("data.json")
user_id = 1
recc = people_you_may_know(user_id, data)
print(recc)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 33
#      31 data = load_data("data.json")
#      32 user_id = 1
# ---> 33 recc = people_you_may_know(user_id, data)
#      34 print(recc)
#
# Cell In[5], line 19, in people_you_may_know(user_id, data)
#      16 suggestions = {}
#      18 for friend in direct_friends:
# ---> 19     for mutual in user_friends['friend']:
#      20         if mutual != user_id and mutual not in direct_friends:
#      21             suggestions[mutual] = suggestions.get(mutual, 0) + 1
#
# KeyError: 'friend'
